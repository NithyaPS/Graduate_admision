# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df=pd.read_csv("https://raw.githubusercontent.com/NithyaPS/Graduate_admision/main/Admission_Predict.csv")
df
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0             1        337          118                  4  4.5   4.5  9.65
# 1             2        324          107                  4  4.0   4.5  8.87
# 2             3        316          104                  3  3.0   3.5  8.00
# 3             4        322          110                  3  3.5   2.5  8.67
# 4             5        314          103                  2  2.0   3.0  8.21
# ..          ...        ...          ...                ...  ...   ...   ...
# 395         396        324          110                  3  3.5   3.5  9.04
# 396         397        325          107                  3  3.0   3.5  9.11
# 397         398        330          116                  4  5.0   4.5  9.45
# 398         399        312          103                  3  3.5   4.0  8.78
# 399         400        333          117                  4  5.0   4.0  9.66
#
#      Research  Chance of Admit
# ...

# %%
df.head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0           1        337          118                  4  4.5   4.5  9.65
# 1           2        324          107                  4  4.0   4.5  8.87
# 2           3        316          104                  3  3.0   3.5  8.00
# 3           4        322          110                  3  3.5   2.5  8.67
# 4           5        314          103                  2  2.0   3.0  8.21
#
#    Research  Chance of Admit
# 0         1              0.92
# 1         1              0.76
# 2         1              0.72
# 3         1              0.80
# 4         0              0.65

# %%
df.tail()
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 395         396        324          110                  3  3.5   3.5  9.04
# 396         397        325          107                  3  3.0   3.5  9.11
# 397         398        330          116                  4  5.0   4.5  9.45
# 398         399        312          103                  3  3.5   4.0  8.78
# 399         400        333          117                  4  5.0   4.0  9.66
#
#      Research  Chance of Admit
# 395         1              0.82
# 396         1              0.84
# 397         1              0.91
# 398         0              0.67
# 399         1              0.95

# %%
df.shape
# Out:
# (400, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Serial No.         400 non-null    int64
#  1   GRE Score          400 non-null    int64
#  2   TOEFL Score        400 non-null    int64
#  3   University Rating  400 non-null    int64
#  4   SOP                400 non-null    float64
#  5   LOR                400 non-null    float64
#  6   CGPA               400 non-null    float64
#  7   Research           400 non-null    int64
#  8   Chance of Admit    400 non-null    float64
# dtypes: float64(4), int64(5)
# memory usage: 28.2 KB

# %%
df.describe()
# Out:
#        Serial No.   GRE Score  TOEFL Score  University Rating         SOP  \
# count  400.000000  400.000000   400.000000         400.000000  400.000000
# mean   200.500000  316.807500   107.410000           3.087500    3.400000
# std    115.614301   11.473646     6.069514           1.143728    1.006869
# min      1.000000  290.000000    92.000000           1.000000    1.000000
# 25%    100.750000  308.000000   103.000000           2.000000    2.500000
# 50%    200.500000  317.000000   107.000000           3.000000    3.500000
# 75%    300.250000  325.000000   112.000000           4.000000    4.000000
# max    400.000000  340.000000   120.000000           5.000000    5.000000
#
#              LOR         CGPA    Research  Chance of Admit
# count  400.000000  400.000000  400.000000        400.000000
# mean     3.452500    8.598925    0.547500          0.724350
# std      0.898478    0.596317    0.498362          0.142609
# min      1.000000    6.800000    0.000000          0.340000
# ...

# %%
df.isnull().sum()
# Out:
# Serial No.           0
# GRE Score            0
# TOEFL Score          0
# University Rating    0
# SOP                  0
# LOR                  0
# CGPA                 0
# Research             0
# Chance of Admit      0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.nunique()
# Out:
# Serial No.           400
# GRE Score             49
# TOEFL Score           29
# University Rating      5
# SOP                    9
# LOR                    9
# CGPA                 168
# Research               2
# Chance of Admit       60
# dtype: int64

# %%
df.columns.values.tolist()
# Out:
# ['Serial No.',
#  'GRE Score',
#  'TOEFL Score',
#  'University Rating',
#  'SOP',
#  'LOR ',
#  'CGPA',
#  'Research',
#  'Chance of Admit ']

# %%
df.rename(columns={'LOR ':'LOR','Chance of Admit ':'Chance of Admit'},inplace=True)

# %%
df.drop(columns='Serial No.',axis=1,inplace=True)

# %%
df.columns
# Out:
# Index(['GRE Score', 'TOEFL Score', 'University Rating', 'SOP', 'LOR', 'CGPA',
#        'Research', 'Chance of Admit'],
#       dtype='object')

# %%
plt.figure(figsize=(15,5))
sns.countplot(x='GRE Score',data=df)
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(15,5))
sns.countplot(x='TOEFL Score',data=df)
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.countplot(x='LOR',data=df)
plt.xticks(rotation=45)
plt.show()

# %%
for col in df:
    plt.boxplot(df[col], vert= False)
    plt.title(col)
    plt.show()

# %%
#Outliers are found in the columns 'LOR','CGPA' and 'Chance Of Admit'
q1 = df['LOR'].quantile(0.25)
q3 = df['LOR'].quantile(0.75)
iqr = q3 - q1

# Define range
lower_range = q1 - 1.5 * iqr
upper_range = q3 + 1.5 * iqr

# Identify outliers
outlier_indices = df[(df['LOR'] < lower_range) | (df['LOR'] > upper_range)].index

# Remove outliers
df = df.drop(outlier_indices)

# %%
q1 = df['CGPA'].quantile(0.25)
q3 = df['CGPA'].quantile(0.75)
iqr = q3 - q1

# Define range
lower_range = q1 - 1.5 * iqr
upper_range = q3 + 1.5 * iqr

# Identify outliers
outlier_indices = df[(df['CGPA'] < lower_range) | (df['CGPA'] > upper_range)].index

# Remove outliers
df = df.drop(outlier_indices)

# %%
q1 = df['Chance of Admit'].quantile(0.25)
q3 = df['Chance of Admit'].quantile(0.75)
iqr = q3 - q1

# Define range
lower_range = q1 - 1.5 * iqr
upper_range = q3 + 1.5 * iqr

# Identify outliers
outlier_indices = df[(df['Chance of Admit'] < lower_range) | (df['Chance of Admit'] > upper_range)].index

# Remove outliers
df = df.drop(outlier_indices)

# %%
for col in df:
    plt.boxplot(df[col], vert= False)
    plt.title(col)
    plt.show()

# %%
sns.countplot(x='Research',data=df)
plt.show()
print(df['Research'].value_counts())
# Out:
# 1    218
# 0    178
# Name: Research, dtype: int64

# %%
plt.figure(figsize=(20,8))
sns.countplot(x='Chance of Admit',data=df)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# The min and max value for chance of admit is 0.34 and 0.97.
# For better evaluation of chances of admission the column must be converted into binary equivalent. When the chance of admit is 1 it means you will get the admission and if it is 0 then no admission.

# %%
df['Chance of admission']=[0 if x<=0.50 else 1 for x in df['Chance of Admit']]

# %%
plt.figure(figsize=(8,5))
sns.countplot(x='Chance of admission',data=df)
plt.show()

# %%
df.columns
# Out:
# Index(['GRE Score', 'TOEFL Score', 'University Rating', 'SOP', 'LOR', 'CGPA',
#        'Research', 'Chance of Admit', 'Chance of admission'],
#       dtype='object')

# %%
df.drop(columns='Chance of Admit',axis=1,inplace=True)

# %%
plt.figure(figsize =(15,6))
sns.scatterplot(y ='Chance of admission', x ='GRE Score', data = df)
plt.show()

# %% [markdown]
# When GRE score is higher the chance of getting admission is high. The maximum score of GRE is 340. For a GRE score of above 320 the chance of admission is very high.

# %%
plt.figure(figsize =(15,6))
sns.scatterplot(y ='Chance of admission', x ='TOEFL Score', data = df)
plt.show()

# %% [markdown]
# The maximum score of TOEFL is 120. For a TOEFL score of above 110 the chance of admission is very high.

# %%
plt.figure(figsize =(15,6))
sns.barplot(y ='Chance of admission', x ='University Rating', data = df)
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.heatmap(df.corr(),annot=True,annot_kws={'size':8})
plt.show()

# %%
x=df.drop(columns=['Chance of admission'])
y=df['Chance of admission']

# %%
from sklearn.preprocessing import StandardScaler
SS=StandardScaler()
x_scaled=SS.fit_transform(x)

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
from sklearn.linear_model import LogisticRegression

acc_score_test = 0
acc_score_train = 0
rand_state = 0
for i in range(1,200):
    
    x_train,x_test,y_train,y_test = train_test_split(x_scaled,y,test_size=0.30,random_state= i )
    
    lr = LogisticRegression()
    lr.fit(x_train,y_train)
    
    y_pred=lr.predict(x_train) # prediction on train data
    r1 =accuracy_score(y_train,y_pred) # accuracy check on train data
    
    pred = lr.predict(x_test)   #prediction on test data
    r2 =accuracy_score(y_test,pred) #accuracy check on test data
    
    if r2 > acc_score_test and r1 > acc_score_train: # selecting max score accuracy
        acc_score_test = r2
        acc_score_train = r1
        rand_state = i
    print(f"at random sate {i}, the training accuracy is:- {acc_score_train}")
    print(f"at random sate {i}, the testing accuracy is:- {acc_score_test}")
    print("\n")
print('Best Training accuracy_score is {} on random state {}'.format(acc_score_train,rand_state))
print('Best Testing accuracy_score is {} on random state {}'.format(acc_score_test,rand_state))
# Out:
# at random sate 1, the training accuracy is:- 0.9566787003610109
# at random sate 1, the testing accuracy is:- 0.9411764705882353
#
#
# at random sate 2, the training accuracy is:- 0.9566787003610109
# at random sate 2, the testing accuracy is:- 0.9411764705882353
#
#
# at random sate 3, the training accuracy is:- 0.9566787003610109
# at random sate 3, the testing accuracy is:- 0.9411764705882353
#
#
# at random sate 4, the training accuracy is:- 0.9566787003610109
# at random sate 4, the testing accuracy is:- 0.9411764705882353
#
#
# at random sate 5, the training accuracy is:- 0.9566787003610109
# at random sate 5, the testing accuracy is:- 0.9411764705882353
#
#
# at random sate 6, the training accuracy is:- 0.9566787003610109
# at random sate 6, the testing accuracy is:- 0.9411764705882353
#
#
# at random sate 7, the training accuracy is:- 0.9566787003610109
# at random sate 7, the testing accuracy is:- 0.9411764705882353
#
#
# ...

# %%
#Lets split for train and test data
x_train,x_test,y_train,y_test = train_test_split(x_scaled,y,test_size=0.30,random_state= rand_state )

# %%
# Lets use of Resampling Techniques to handle Imbalanced Data 
from imblearn.over_sampling import SMOTE
from collections import Counter

ove_smp=SMOTE()
x_train_ns,y_train_ns=ove_smp.fit_resample(x_train,y_train)
print(Counter(y_train))
print(Counter(y_train_ns))
# Out:
# Counter({1: 253, 0: 24})
# Counter({1: 253, 0: 253})

# %%
# !pip install imbalanced-learn
# Out:
# ...
# [notice] A new release of pip is available: 23.1.2 -> 23.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from sklearn.linear_model import LogisticRegression
LR= LogisticRegression()

from sklearn.tree import DecisionTreeClassifier
dt=DecisionTreeClassifier()

from sklearn.ensemble import AdaBoostClassifier, GradientBoostingClassifier
ada=AdaBoostClassifier()
gb=GradientBoostingClassifier()

from sklearn.ensemble import RandomForestClassifier
rfc= RandomForestClassifier()

from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier()

from sklearn.model_selection import cross_val_score


models=[]
models.append(('LogisticRegression', LR))
models.append(('DecisionTreeClassifier', dt))
models.append(('AdaBoostClassifier', ada))
models.append(('GradientBoostingClassifier', gb))
models.append(('RandomForestClassifier', rfc))
models.append(('KNeighborsClassifier', knn))

# %%
m=[]
score=[]
score2=[]
cv_score=[]

for name, model in models:
    print(name)
    m.append(name)
    model.fit(x_train, y_train)
    print(model)
    y_pred=model.predict(x_train)
    AS=accuracy_score(y_train,y_pred)
    print("Train Report:",AS)
    score.append(AS*100)
    
    pred=model.predict(x_test)
    AS2=accuracy_score(y_test,pred)
    print("Test Report:",AS2)
    score2.append(AS2*100)
    CR=classification_report(y_test,pred)
    print("classification report:",CR)
    CM=confusion_matrix(y_test,pred)
    print("confusion matrix:", CM)
      
    accuracies= cross_val_score(model,x,y, cv=2)
    print("Accuracy: {:.2f} %".format(accuracies.mean()*100))
    cv_score.append(accuracies.mean()*100)
    print("Standard Deviation: {:.2f} %".format(accuracies.std()*100))
    print('\n')
# Out:
# LogisticRegression
# LogisticRegression()
# Train Report: 0.9602888086642599
# Test Report: 0.9495798319327731
# classification report:               precision    recall  f1-score   support
#
#            0       0.67      0.29      0.40         7
#            1       0.96      0.99      0.97       112
#
#     accuracy                           0.95       119
#    macro avg       0.81      0.64      0.69       119
# weighted avg       0.94      0.95      0.94       119
#
# confusion matrix: [[  2   5]
#  [  1 111]]
# Accuracy: 91.16 %
# Standard Deviation: 0.25 %
#
#
# DecisionTreeClassifier
# DecisionTreeClassifier()
# Train Report: 1.0
# Test Report: 0.9327731092436975
# classification report:               precision    recall  f1-score   support
#
#            0       0.43      0.43      0.43         7
#            1       0.96      0.96      0.96       112
#
#     accuracy                           0.93       119
#    macro avg       0.70      0.70      0.70       119
# ...

# %%
result = pd.DataFrame({'Model': m, 'Accuracy_train_score': score,'Accuracy_test_score': score2 ,'Cross_val_score':cv_score})
result
# Out:
#                         Model  Accuracy_train_score  Accuracy_test_score  \
# 0          LogisticRegression             96.028881            94.957983
# 1      DecisionTreeClassifier            100.000000            93.277311
# 2          AdaBoostClassifier            100.000000            93.277311
# 3  GradientBoostingClassifier            100.000000            92.436975
# 4      RandomForestClassifier            100.000000            95.798319
# 5        KNeighborsClassifier             93.501805            94.117647
#
#    Cross_val_score
# 0        91.161616
# 1        89.646465
# 2        89.898990
# 3        91.919192
# 4        93.181818
# 5        93.181818

# %% [markdown]
# # Random forest classifier is chosen as the best model
